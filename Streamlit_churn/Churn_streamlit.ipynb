# %%
# streamlit으로 모델 구현하기

# %%
# !pip install streamlit pandas scikit-learn
# Out:
# Requirement already satisfied: streamlit in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (1.39.0)
# Requirement already satisfied: pandas in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (1.5.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (13.9.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<6,>=2.1.5 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: jinja2 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from altair<6,>=4.0->streamlit) (1.9.3)
# Requirement already satisfied: colorama in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: six>=1.5 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from requests<3,>=2.27->streamlit) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\playdata\appdata\local\anaconda3\envs\pypandas\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)

# %%
import streamlit as st
import pickle
import pandas as pd

# Load the trained model
with open('model_gbm.pkl', 'rb') as file:
    model = pickle.load(file)

# Define the prediction function
def predict_churn(features):
    prediction = model.predict_proba([features])
    return prediction[0][1]  # Probability of churn

# Streamlit app
st.title("Customer Churn Prediction")

# Create input fields for each feature in the specified order
features = []

# Group features in threes based on the specified order
feature_groups = [
    # Group 1
    [
        ('Gender', ['Male', 'Female'], lambda x: 1 if x == 'Male' else 0),
        ('Tenure Months', ['0-24', '25-48', '49-72'], lambda x: {"0-24": 0, "25-48": 1, "49-72": 2}[x]),
        ('Phone Service', ['Yes', 'No'], lambda x: 1 if x == 'Yes' else 0)
    ],
    # Group 2
    [
        ('Multiple Lines', ['No', 'Yes', 'No phone service'], lambda x: {'No': 0, 'Yes': 2, 'No phone service': 1}[x]),
        ('Internet Service', ['DSL', 'Fiber optic', 'No'], lambda x: {'DSL': 0, 'Fiber optic': 1, 'No': 2}[x]),
        ('Online Security', ['Yes', 'No', 'No internet service'], lambda x: {'Yes': 2, 'No': 0, 'No internet service': 1}[x])
    ],
    # Group 3
    [
        ('Online Backup', ['Yes', 'No', 'No internet service'], lambda x: {'Yes': 2, 'No': 0, 'No internet service': 1}[x]),
        ('Device Protection', ['Yes', 'No', 'No internet service'], lambda x: {'Yes': 2, 'No': 0, 'No internet service': 1}[x]),
        ('Tech Support', ['Yes', 'No', 'No internet service'], lambda x: {'Yes': 2, 'No': 0, 'No internet service': 1}[x])
    ],
    # Group 4
    [
        ('Streaming TV', ['Yes', 'No', 'No internet service'], lambda x: {'Yes': 2, 'No': 0, 'No internet service': 1}[x]),
        ('Streaming Movies', ['Yes', 'No', 'No internet service'], lambda x: {'Yes': 2, 'No': 0, 'No internet service': 1}[x]),
        ('Contract', ['Month-to-month', 'One year', 'Two year'], lambda x: {'Month-to-month': 0, 'One year': 1, 'Two year': 2}[x])
    ],
    # Group 5
    [
        ('Total Charges', ["0-4351", "4352-9000"], lambda x: {"0-4351": 0, "4352-9000": 1}[x]),
        ('Churn Value', ['Yes', 'No'], lambda x: 1 if x == 'Yes' else 0),  # Adjust if Churn Value needs special handling
        ('CLTV', ["0-3502", "3503-5001", "5002-6500"], lambda x: {"0-3502": 0, "3503-5001": 1, "5002-6500": 2}[x])
    ],
    # Group 6
    [
        ('Age', ["0-17", "18-44", "45-64", "65+"], lambda x: {"0-17": 0, "18-44": 1, "45-64": 2, "65+": 3}[x]),
        ('Married', ['Yes', 'No'], lambda x: 1 if x == 'Yes' else 0),
        ('Number of Dependents', ['0', '1', '2', '3+'], lambda x: {"0": 0, "1": 1, "2": 2, "3+": 3}[x])
    ],
    # Group 7
    [
        ('Referred a Friend', ['Yes', 'No'], lambda x: 1 if x == 'Yes' else 0),
        ('Offer', ['None', 'Offer A', 'Offer B', 'Offer C', 'Offer D', 'Offer E'], 
         lambda x: {'None': 0, 'Offer A': 1, 'Offer B': 2, 'Offer C': 3, 'Offer D': 4, 'Offer E': 5}[x]),
        ('Avg Monthly GB Download', ["0-28", "29-56", "57-100"], lambda x: {"0-28": 0, "29-56": 1, "57-100": 2}[x])
    ],
    # Group 8
    [
        ('Streaming Music', ['Yes', 'No'], lambda x: 1 if x == 'Yes' else 0),
        ('Unlimited Data', ['Yes', 'No'], lambda x: 1 if x == 'Yes' else 0),
        ('Monthly Charge', ["0-51", "52-85", "86-120"], lambda x: {"0-51": 0, "52-85": 1, "86-120": 2}[x])
    ],
    # Group 9
    [
        ('Total Refunds', ["0-16", "17-33", "34-50"], lambda x: {"0-16": 0, "17-33": 1, "34-50": 2}[x]),
        ('Total Extra Data Charges', ["0-50", "51-100", "101-150"], lambda x: {"0-50": 0, "51-100": 1, "101-150": 2}[x]),
        ('Total Long Distance Charges', ["0-1188", "1199-2376", "2377-3565"], lambda x: {"0-1188": 0, "1199-2376": 1, "2377-3565": 2}[x])
    ],
    # Group 10
    [
        ('Total Revenue', ["0-4007", "4008-7993", "7994-12000"], lambda x: {"0-4007": 0, "4008-7993": 1, "7994-12000": 2}[x]),
        ('Satisfaction Score', ['1', '2', '3', '4', '5'], lambda x: int(x)),
        # Placeholder for any additional features
    ]
]

for group in feature_groups:
    cols = st.columns(len(group))
    for col, (label, options, encoding) in zip(cols, group):
        with col:
            value = st.selectbox(label, options)
            encoded_value = encoding(value)
            features.append(encoded_value)

if st.button("Predict"):
    print(features)  # Add this line to debug
    probability = predict_churn(features)
    st.success(f"The probability of customer churn is: {probability:.2f}")


# Predict button
if st.button("Predict"):
    probability = predict_churn(features)
    st.success(f"The probability of customer churn is: {probability:.2f}")
# Out:
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pypandas\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pypandas\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pypandas\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pypandas\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pypandas\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StackingClassifier from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2024-10-17 09:50:52.031 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.808
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Playdata\AppData\Local\anaconda3\envs\pypandas\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-10-17 09:50:52.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.818 Session state does not function when running a script without `streamlit run`
# 2024-10-17 09:50:52.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 09:50:52.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# streamlit run Churn.py
